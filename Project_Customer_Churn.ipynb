# %% [markdown]
# # **Problem Statement:**
#
# You are the data scientist at a telecom company named “Neo” whose customers
# are churning out to its competitors. You have to analyze the data of your
# company and find insights and stop your customers from churning out to other
# telecom companies.

# %%
## import the required library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
## Upload and read the dataset
df = pd.read_csv('/content/customer_churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
## check the shape of the data, it will present the number of rows and coulumns
print(f"The shape of the data is {df.shape}")
# Out:
# The shape of the data is (7043, 21)

# %%
## check the description of the data, it will show the mathematical description of data
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
##check the info of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
##chech the null values
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
## check the duplicate  data
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # **Tasks To Be Performed:**

# %% [markdown]
# 1. **Data Manipulation:**
#
# ● Extract the 5th column and store it in ‘customer_5’
#
# ● Extract the 15th column and store it in ‘customer_15’
#
# ● Extract all the male senior citizens whose payment method is electronic
# check and store the result in ‘senior_male_electronic’
#
# ● Extract all those customers whose tenure is greater than 70 months or
# their monthly charges is more than $100 and store the result in
# ‘customer_total_tenure’
#
# ● Extract all the customers whose contract is of two years, payment method
# is mailed check and the value of churn is ‘Yes’ and store the result in
# ‘two_mail_yes’
#
# ● Extract 333 random records from the customer_churndataframe and store
# the result in ‘customer_333’
#
# ● Get the count of different levels from the ‘Churn’ column

# %%
#Extract the 5th column and store it in ‘customer_5’
customer_5 = df.iloc[:, 4]
customer_5
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040    Yes
# 7041     No
# 7042     No
# Name: Dependents, Length: 7043, dtype: object

# %%
#Extract the 15th column and store it in ‘customer_15’
customer_15 = df.iloc[:, 14]
customer_15
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040     No
# 7041     No
# 7042    Yes
# Name: StreamingMovies, Length: 7043, dtype: object

# %%
#Extract all the male senior citizens whose payment method is electronic check and store the result in ‘senior_male_electronic’
senior_male_electronic = df[(df['gender'] == 'Male') & (df['SeniorCitizen'] == 1) & (df['PaymentMethod'] == 'Electronic check')]
senior_male_electronic
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV   Male              1      No         No       1
# 55    1658-BYGOY   Male              1      No         No      18
# 57    5067-XJQFU   Male              1     Yes        Yes      66
# 78    0191-ZHSKZ   Male              1      No         No      30
# 91    2424-WVHPL   Male              1      No         No       1
# ...          ...    ...            ...     ...        ...     ...
# 6837  6229-LSCKB   Male              1      No         No       6
# 6894  1400-MMYXY   Male              1     Yes         No       3
# 6914  7142-HVGBG   Male              1     Yes         No      43
# 6967  8739-WWKDU   Male              1      No         No      25
# 7032  6894-LFHLY   Male              1      No         No       1
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# ...

# %%
#Extract all those customers whose tenure is greater than 70 months or their monthly charges is more than
#$100 and store the result in ‘customer_total_tenure’
customer_total_tenure = df[(df['tenure'] > 70) | (df['MonthlyCharges'] > 100)]
customer_total_tenure
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7034  0639-TSIQW  Female              0      No         No      67
# 7037  2569-WGERO  Female              0      No         No      72
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 8             Yes           Yes     Fiber optic                   No  ...
# ...

# %%
#Extract all the customers whose contract is of two years, payment method
#is mailed check and the value of churn is ‘Yes’ and store the result in
#‘two_mail_yes’
two_mail_yes = df[(df['Contract'] == 'Two year') & (df['PaymentMethod'] == 'Mailed check') & (df['Churn'] == 'Yes')]
two_mail_yes
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 268   6323-AYBRX    Male              0      No         No      59
# 5947  7951-QKZPL  Female              0     Yes        Yes      33
# 6680  9412-ARGBX  Female              0      No        Yes      48
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 268           Yes            No              No  No internet service  ...
# 5947          Yes           Yes              No  No internet service  ...
# 6680          Yes            No     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 268   No internet service  No internet service  No internet service
# 5947  No internet service  No internet service  No internet service
# 6680                  Yes                  Yes                  Yes
#
#           StreamingMovies  Contract PaperlessBilling PaymentMethod  \
# ...

# %%
#Extract 333 random records from the customer_churndataframe and store the result in ‘customer_333’
customer_333 = df.sample(n=333)
customer_333
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3439  0917-EZOLA    Male              1     Yes         No      72
# 5085  7074-STDCN    Male              0      No         No      39
# 358   9057-MSWCO    Male              1     Yes         No      27
# 3504  3678-MNGZX    Male              0     Yes        Yes      68
# 5751  0932-YIXYU  Female              0      No         No      47
# ...          ...     ...            ...     ...        ...     ...
# 5268  2885-HIJDH    Male              0     Yes        Yes      69
# 3900  8008-OTEZX  Female              0     Yes        Yes      35
# 6850  0531-XBKMM    Male              0      No        Yes      66
# 6772  7931-PXHFC    Male              0      No         No      38
# 5306  5940-NFXKV    Male              0     Yes        Yes      19
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 3439          Yes               Yes     Fiber optic                   No  ...
# ...

# %%
#Get the count of different levels from the ‘Churn’ column
churn_counts = df['Churn'].value_counts()
churn_counts
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# # **2. Data Visualization:**
# ● Build a bar-plot for the ’InternetService’ column:
#
# a. Set x-axis label to ‘Categories of Internet Service’
#
# b. Set y-axis label to ‘Count of Categories’
#
# c. Set the title of plot to be ‘Distribution of Internet Service’
#
# d. Set the color of the bars to be ‘orange

# %%
fig = px.bar(df, x='InternetService', title='Distribution of Internet Service', color_discrete_sequence=['red'])
fig.update_layout(xaxis_title='Categories of Internet Service', yaxis_title='Count of Categories')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Build a histogram for the ‘tenure columns**
#
# a. set the number bins to be 30
#
# b set the color of bins to be green
#
# c.assign the title 'distribution of tenure"

# %%
fig = px.histogram(df, x = "tenure", color_discrete_sequence=['green'], title='Distribution of tenure', nbins=30)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ● Build a scatter-plot between ‘MonthlyCharges’ and ‘tenure’. Map
# ‘MonthlyCharges’ to the y-axis and ‘tenure’ to the ‘x-axis’:
#
# a. Assign the points a color of ‘brown’
#
# b. Set the x-axis label to ‘Tenure of customer’
#
# c. Set the y-axis label to ‘Monthly Charges of customer’
#
# d. Set the title to ‘Tenure vs Monthly Charges’
#
# e. Build a box-plot between ‘tenure’ & ‘Contract’. Map ‘tenure’ on the
# y-axis &
#
# f. ‘Contract’ on the x-axis.

# %%
fig = px.scatter(df,x="tenure", y = "MonthlyCharges",color_discrete_sequence = ["brown"], title = "Tenure vs Monthly Charges")
fig.update_layout(xaxis_title="Tenure of customer", yaxis_title="Monthly Charges of customer")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
##box plot
fig = px.box(df, x="tenure", y="Contract")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **ML_PROCESS**

# %%
## check the outliers
#outliers -boxplot
for i in df.columns:
  if(df[i].dtypes != 'object'):
    plt.boxplot(df[i])
    plt.xlabel(i)
    plt.show()

# %%
## chenage the object data type, for this import the labelEncoder
from sklearn.preprocessing import LabelEncoder

# %%
## Assign the variable
le = LabelEncoder()

# %%
for col in df.columns:
  if (df[col].dtype =='object'):
    df[col]= le.fit_transform(df[col])

# %% [markdown]
# 3. Linear Regression:
#
# ● Build a simple linear model where dependent variable is ‘MonthlyCharges’
# and independent variable is ‘tenure’:
#
# a. Divide the dataset into train and test sets in 70:30 ratio.
#
# b. Build the model on train set and predict the values on test set
#
# c. After predicting the values, find the root mean square error
#
# d. Find out the error in prediction & store the result in ‘error’
#
# e. Find the root mean square error

# %%
#target columns: churn
x = df['tenure']
y = df['MonthlyCharges']

#training
#testing
#evaluation

# %%
#split the data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=1)

# %%
## import the Linear regression model
from sklearn.linear_model import LinearRegression

# %%
##Assig the variable
my_model = LinearRegression()

# %%
## Trainig
my_model.fit(x_train.values.reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
##Testing
y_pred = my_model.predict(x_test.values.reshape(-1, 1))

# %%
## check the y_Pred
y_pred
# Out:
# array([67.51532767, 75.26743764, 58.5228801 , ..., 61.31363969,
#        76.50777524, 68.75566526])

# %%
y_test
# Out:
# 3381     79.85
# 6180    102.40
# 4829     45.00
# 3737     50.60
# 4249     65.90
#          ...
# 3934     40.25
# 1351     20.45
# 2048     96.80
# 6218     58.40
# 4297     73.55
# Name: MonthlyCharges, Length: 2113, dtype: float64

# %%
## Assignig the name for the y_pred, y_test
result = pd.DataFrame(columns = ['Actual value-ytest','predicted_values-y_pred'])
result['Actual value-ytest'] = y_test
result['predicted_values-y_pred'] = y_pred

# %%
result
# Out:
#       Actual value-ytest  predicted_values-y_pred
# 3381               79.85                67.515328
# 6180              102.40                75.267438
# 4829               45.00                58.522880
# 3737               50.60                56.352289
# 4249               65.90                57.902711
# ...                  ...                      ...
# 3934               40.25                57.902711
# 1351               20.45                58.212796
# 2048               96.80                61.313640
# 6218               58.40                76.507775
# 4297               73.55                68.755665
#
# [2113 rows x 2 columns]

# %%
from sklearn.metrics import *

# %%
## Check the accuracy
result = r2_score(y_test,y_pred)

# %%
result
# Out:
# 0.05563865568825355

# %%
##root_mean_square_error
error = np.sqrt(mean_squared_error(y_test,y_pred))
error
# Out:
# np.float64(29.15550989402921)

# %% [markdown]
# 4. Logistic Regression:
#
# ● Build a simple logistic regression model where dependent variable is
# ‘Churn’ and independent variable is ‘MonthlyCharges’:
#
# a. Divide the dataset in 65:35 ratio
#
# b. Build the model on train set and predict the values on test set
#
# c. Build the confusion matrix and get the accuracy score
#
# d. Build a multiple logistic regression model where dependent variable
# is ‘Churn’ and independent variables are ‘tenure’ and
# ‘MonthlyCharges’
#
# e. Divide the dataset in 80:20 ratio
#
# f. Build the model on train set and predict the values on test set
#
# g. Build the confusion matrix and get the accuracy score

# %%
## take the variable
x1 = df['MonthlyCharges']
y1= df['Churn']

# %%
## Split the data
from sklearn.model_selection import train_test_split
x1_train,x1_test,y1_train,y1_test = train_test_split(x1,y1,test_size=0.35,random_state=60)

# %%
##import the package for the Logistic Model
from sklearn.linear_model import LogisticRegression

# %%
## from sklearn import all
from sklearn.metrics import *

# %%
## train the model
model = LogisticRegression()
model.fit(x1_train.values.reshape(-1, 1), y1_train)
# Out:
# LogisticRegression()

# %%
### Predict
y1_pred = model.predict(x1_test.values.reshape(-1, 1))

# %%
confusion_matrix= confusion_matrix(y1_pred,y1_test,)
confusion_matrix
# Out:
# array([[1809,  657],
#        [   0,    0]])

# %%
##Check the accuracy
accuracy_score(y1_pred,y1_test)
# Out:
# 0.7335766423357665

# %% [markdown]
# # **Logistic Regression**

# %%
## take the variable
x2 = df[['tenure','MonthlyCharges']]
y2 = df['Churn']

# %%
## split the data
from sklearn.model_selection import train_test_split
x2_train,x2_test,y2_train,y2_test = train_test_split(x2,y2,test_size=0.2,random_state=60)

# %%
## import the package for the logistic regression model
from sklearn.linear_model import LogisticRegression

# %%
#assign the variable
model2 = LogisticRegression()

# %%
## Train the model
model2.fit(x2_train,y2_train)
# Out:
# LogisticRegression()

# %%
## Test the model
y2_pred = model2.predict(x2_test)

# %%
## Check the confusion Matrix
confusion_matrix =(y2_pred,y2_test)
confusion_matrix
# Out:
# (array([0, 0, 0, ..., 0, 0, 0]),
#  6644    0
#  374     0
#  4363    0
#  3631    1
#  3888    1
#         ..
#  2245    0
#  6047    0
#  3169    0
#  437     0
#  638     1
#  Name: Churn, Length: 1409, dtype: int64)

# %%
## Check the accuracy
accuracy_score(y2_pred,y2_test)
# Out:
# 0.7792760823278921

# %% [markdown]
# # **5. Decision Tree:**
#
# ● Build a decision tree model where dependent variable is ‘Churn’ and
#
# independent variable is ‘tenure’:
#
# a. Divide the dataset in 80:20 ratio
#
# b. Build the model on train set and predict the values on test set
#
# c. Build the confusion matrix and calculate the accuracy

# %%
## Take variable for data
x3 = df['tenure']
y3 = df['Churn']

# %%
##Split the data
from sklearn.model_selection import train_test_split
x3_train,x3_test,y3_train,y3_test = train_test_split(x3,y3,test_size=0.2,random_state=64)

# %%
## import the the Decision Tree Model
from sklearn.tree import DecisionTreeClassifier

# %%
## check the x_train
x3_train
# Out:
# 2389    71
# 6577    70
# 2644    18
# 4232     1
# 1432    35
#         ..
# 54      60
# 3238    26
# 6263    25
# 5094    65
# 6596    64
# Name: tenure, Length: 5634, dtype: int64

# %%
## Check the Y_Train
y3_train
# Out:
# 2389    0
# 6577    0
# 2644    1
# 4232    1
# 1432    0
#        ..
# 54      0
# 3238    0
# 6263    0
# 5094    0
# 6596    0
# Name: Churn, Length: 5634, dtype: int64

# %%
## Train the model
model3 = DecisionTreeClassifier()
model3.fit(x3_train.values.reshape(-1, 1), y3_train)
# Out:
# DecisionTreeClassifier()

# %%
## Test the model
y3_pred = model3.predict(x3_test.values.reshape(-1, 1))

# %%
## Check the confusion matrix
confusion_matrix = (y3_pred,y3_test)
confusion_matrix
# Out:
# (array([0, 0, 0, ..., 0, 0, 0]),
#  1035    0
#  639     1
#  6056    0
#  4603    0
#  2627    0
#         ..
#  174     0
#  933     1
#  6989    0
#  626     0
#  2225    0
#  Name: Churn, Length: 1409, dtype: int64)

# %%
## get the accuracy
accuracy_score(y3_pred,y3_test)
# Out:
# 0.7487579843860894

# %% [markdown]
# # **6. Random Forest:**
#
# ● Build a Random Forest model where dependent variable is ‘Churn’ and
# independent variables are ‘tenure’ and ‘MonthlyCharges’:
#
# a. Divide the dataset in 70:30 ratio
#
# b. Build the model on train set and predict the values on test set
#
# c. Build the confusion matrix and calculate the accuracy

# %%
## take the variable for the data
x4 = df[['tenure','MonthlyCharges']]
y4 = df['Churn']

# %%
### split the data
from sklearn.model_selection import train_test_split
x4_train,x4_test,y4_train,y4_test = train_test_split(x4,y4,test_size=0.3,random_state=60)

# %%
## import the model for RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
## Train the data
model4 = RandomForestClassifier()
model4.fit(x4_train,y4_train)
# Out:
# RandomForestClassifier()

# %%
## Test the data
y4_pred = model4.predict(x4_test)

# %%
## check the confusion Matrix
confusion_matrix = (y4_pred,y4_test)
confusion_matrix
# Out:
# (array([0, 1, 0, ..., 0, 0, 0]),
#  6644    0
#  374     0
#  4363    0
#  3631    1
#  3888    1
#         ..
#  646     1
#  2184    1
#  2549    0
#  146     0
#  4810    1
#  Name: Churn, Length: 2113, dtype: int64)

# %%
## Check the accuracy score
accuracy_score(y4_pred,y4_test)
# Out:
# 0.7458589682915286
